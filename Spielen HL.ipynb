# %%
from src.IOSystem import IOSystem
from src.SupplyChain import SupplyChain

# %%
database = IOSystem(year=2022, language="german").load()
# Out:
# 2025-03-30 11:54:01,948 - INFO - Fast database was found - Loading...
# 2025-03-30 11:54:03,175 - INFO - Database has been loaded successfully in 1.23 seconds.

# %%
supplychain = SupplyChain(database=database, select=True)

# %%
supplychain.plot_supply_chain(impacts=["Treibhausgasemissionen", "Wasserverbrauch", "Landnutzung", "Wertschöpfung", "Arbeitszeit"])

# %%
supplychain.calculate_all(impacts=["Treibhausgasemissionen", "Wasserverbrauch", "Landnutzung", "Wertschöpfung", "Arbeitszeit"], relative=False, decimal_places=5)
# Out:
#                         Rohstoff-\ngewinnung  Produktion\nvon\nVorprodukten  \
# Treibhausgasemissionen                918.15                         991.02
# Wasserverbrauch                     45857.08                        5831.14
# Landnutzung                       3519405.00                           0.00
# Wertschöpfung                      415111.25                     1824445.75
# Arbeitszeit                        106417.96                      113826.71
#
#                         Direkte\nZulieferer  Einzelhandel      Gesamt  \
# Treibhausgasemissionen               625.81        932.02     3467.00
# Wasserverbrauch                     3599.91       4830.00    60118.13
# Landnutzung                            0.00          0.00  3519405.00
# Wertschöpfung                    1462707.50    2268328.00  5970593.00
# Arbeitszeit                        84860.24     145197.92   450302.84
#
#                                   Einheit    Farbe
# Treibhausgasemissionen  Megatonnen CO2-eq  #c7c7c6
# Wasserverbrauch                Mm3 Wasser  #3e9cbf
# Landnutzung                           km2  #5ea545
# Wertschöpfung             Milliarden Euro  #FFD700
# Arbeitszeit             Millionen Stunden  #ff6666

# %%
supplychain.plot_subcontractors(color="Blues")
# Out:
# c:\Users\hendrik.lambrecht\MyPython\HectorMRIO\exiobase_explorer\src\SupplyChain.py:443: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cbar.ax.set_yticklabels([f"{int(tick)}%" for tick in cbar.get_ticks()])
